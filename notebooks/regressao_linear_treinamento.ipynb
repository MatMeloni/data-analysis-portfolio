# %% [markdown]
# 📘 Atividade 1 — Regressão Linear Simples

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Dados da atividade
horas_treinamento = np.array([5.2, 5.1, 4.9, 4.6, 4.7, 4.8, 4.6, 4.9]).reshape(-1, 1)
tempo_trabalho = np.array([13, 15, 16, 20, 19, 17, 21, 16])

# Criando o modelo
modelo = LinearRegression()
modelo.fit(horas_treinamento, tempo_trabalho)

# Previsão
tempo_predito = modelo.predict(horas_treinamento)

# Parâmetros do modelo
coef_angular = modelo.coef_[0]
intercepto = modelo.intercept_
mse = mean_squared_error(tempo_trabalho, tempo_predito)

# Resultados
print(f'Equação da reta: y = {coef_angular:.2f}x + {intercepto:.2f}')
print(f'MSE: {mse:.2f}')
# Out:
# Equação da reta: y = -11.91x + 74.90
# MSE: 0.33

# %%
# Gráfico de dispersão com linha de regressão
plt.figure(figsize=(10, 5))
plt.scatter(horas_treinamento, tempo_trabalho, color='blue', label='Dados reais')
plt.plot(horas_treinamento, tempo_predito, color='red', label='Linha de regressão')
plt.xlabel("Horas de Treinamento")
plt.ylabel("Tempo para completar o trabalho")
plt.title("Atividade Prática: Introdução à Modelagem Estatística e Análise de Regressão Simples")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# O coeficiente angular **(-11,91)** indica que quanto mais treinamento, menor o tempo de execução.
#
# O intercepto **(74,90)** indica o tempo teórico para alguém sem treinamento.
#
# O Erro Quadrático Médio (MSE) foi de **0,33**, o que representa bom ajuste do modelo para esses dados.

# %% [markdown]
# **Atividade 2**
